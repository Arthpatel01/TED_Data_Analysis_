# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pandas.io.json import read_json
from wordcloud import WordCloud, STOPWORDS

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
day_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
df = pd.read_csv('ted_main.csv')

# %%
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views'],
#       dtype='object')

# %%
df = df[['name', 'title', 'description', 'main_speaker', 'speaker_occupation', 'num_speaker', 'duration', 'event',
         'film_date', 'published_date', 'comments', 'tags', 'languages', 'ratings', 'related_talks', 'url', 'views']]

# %%
df.head()
# Out:
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                          description   main_speaker  \
# 0  Sir Ken Robinson makes an entertaining and pro...   Ken Robinson
# 1  With the same humor and humanity he exuded in ...        Al Gore
# 2  New York Times columnist David Pogue takes aim...    David Pogue
# 3  In an emotionally charged talk, MacArthur-winn...  Majora Carter
# 4  You've never seen data presented like this. Wi...   Hans Rosling
#
# ...

# %%
import datetime

df['film_date'] = df['film_date'].apply(lambda x: datetime.datetime.fromtimestamp(int(x)).strftime('%d-%m-%Y'))

# %%
df.head()
# Out:
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                          description   main_speaker  \
# 0  Sir Ken Robinson makes an entertaining and pro...   Ken Robinson
# 1  With the same humor and humanity he exuded in ...        Al Gore
# 2  New York Times columnist David Pogue takes aim...    David Pogue
# 3  In an emotionally charged talk, MacArthur-winn...  Majora Carter
# 4  You've never seen data presented like this. Wi...   Hans Rosling
#
# ...

# %%
df['published_date'] = df['published_date'].apply(
    lambda x: datetime.datetime.fromtimestamp(int(x)).strftime('%d-%m-%Y'))
df.head()
# Out:
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                          description   main_speaker  \
# 0  Sir Ken Robinson makes an entertaining and pro...   Ken Robinson
# 1  With the same humor and humanity he exuded in ...        Al Gore
# 2  New York Times columnist David Pogue takes aim...    David Pogue
# 3  In an emotionally charged talk, MacArthur-winn...  Majora Carter
# 4  You've never seen data presented like this. Wi...   Hans Rosling
#
# ...

# %%
df.shape
# Out:
# (2550, 17)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                    name  \
# 0             Ken Robinson: Do schools kill creativity?
# 1                  Al Gore: Averting the climate crisis
# 2                         David Pogue: Simplicity sells
# 3                    Majora Carter: Greening the ghetto
# 4         Hans Rosling: The best stats you've ever seen
# ...                                                 ...
# 2545  Duarte Geraldino: What we're missing in the de...
# 2546  Armando Azua-Bustos: The most Martian place on...
# 2547  Radhika Nagpal: What intelligent machines can ...
# 2548  Theo E.J. Wilson: A black man goes undercover ...
# 2549  Karoliina Korppoo: How a video game might help...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 1                           Averting the climate crisis
# 2                                      Simplicity sells
# ...

# %%
df.describe()
# Out:
#        num_speaker     duration     comments    languages         views
# count  2550.000000  2550.000000  2550.000000  2550.000000  2.550000e+03
# mean      1.028235   826.510196   191.562353    27.326275  1.698297e+06
# std       0.207705   374.009138   282.315223     9.563452  2.498479e+06
# min       1.000000   135.000000     2.000000     0.000000  5.044300e+04
# 25%       1.000000   577.000000    63.000000    23.000000  7.557928e+05
# 50%       1.000000   848.000000   118.000000    28.000000  1.124524e+06
# 75%       1.000000  1046.750000   221.750000    33.000000  1.700760e+06
# max       5.000000  5256.000000  6404.000000    72.000000  4.722711e+07

# %%
popular_talks = df[['title', 'main_speaker', 'views', 'film_date']].sort_values('views', ascending=False)[:15]
popular_talks
# Out:
#                                                   title       main_speaker  \
# 0                           Do schools kill creativity?       Ken Robinson
# 1346           Your body language may shape who you are          Amy Cuddy
# 677                    How great leaders inspire action        Simon Sinek
# 837                          The power of vulnerability        Brené Brown
# 452              10 things you didn't know about orgasm         Mary Roach
# 1776         How to speak so that people want to listen    Julian Treasure
# 201                                My stroke of insight  Jill Bolte Taylor
# 5                                  Why we do what we do       Tony Robbins
# 2114  This is what happens when you reply to spam email       James Veitch
# 1416  Looks aren't everything. Believe me, I'm a model.    Cameron Russell
# 500                            The puzzle of motivation           Dan Pink
# ...

# %%
popular_talks['abbr'] = popular_talks['main_speaker'].apply(lambda x: x[:3])
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(data=popular_talks, x='abbr', y='views')
# Out:
# <Axes: xlabel='abbr', ylabel='views'>

# %%
sns.displot(df['views'])

# %%
sns.displot(df[df['views'] < 0.4e7]['views'])

# %%
df['views'].describe()
# Out:
# count    2.550000e+03
# mean     1.698297e+06
# std      2.498479e+06
# min      5.044300e+04
# 25%      7.557928e+05
# 50%      1.124524e+06
# 75%      1.700760e+06
# max      4.722711e+07
# Name: views, dtype: float64

# %%
df['comments']
# Out:
# 0       4553
# 1        265
# 2        124
# 3        200
# 4        593
#         ...
# 2545      17
# 2546       6
# 2547      10
# 2548      32
# 2549       8
# Name: comments, Length: 2550, dtype: int64

# %%
df['comments'].describe()
# Out:
# count    2550.000000
# mean      191.562353
# std       282.315223
# min         2.000000
# 25%        63.000000
# 50%       118.000000
# 75%       221.750000
# max      6404.000000
# Name: comments, dtype: float64

# %%
sns.displot(df['comments'])

# %%
sns.displot(df[df['comments'] < 500]['comments'])

# %%
sns.jointplot(data=df, x='views', y='comments')

# %%
df[['views', 'comments']].corr()
# Out:
#              views  comments
# views     1.000000  0.530939
# comments  0.530939  1.000000

# %%
df[['title', 'main_speaker', 'views', 'comments']].sort_values('comments', ascending=False).head(10)
# Out:
#                                          title       main_speaker     views  \
# 96                            Militant atheism    Richard Dawkins   4374792
# 0                  Do schools kill creativity?       Ken Robinson  47227110
# 644         Science can answer moral questions         Sam Harris   3433437
# 201                       My stroke of insight  Jill Bolte Taylor  21190883
# 1787         How do you explain consciousness?     David Chalmers   2162764
# 954               Taking imagination seriously     Janet Echelman   1832930
# 840                       On reading the Koran    Lesley Hazleton   1847256
# 1346  Your body language may shape who you are          Amy Cuddy  43155405
# 661               The danger of science denial    Michael Specter   1838628
# 677           How great leaders inspire action        Simon Sinek  34309432
#
#       comments
# 96        6404
# 0         4553
# 644       3356
# 201       2877
# 1787      2673
# 954       2492
# 840       2374
# ...

# %%
df['dis_quo'] = df['comments'] / df['views']

# %%
df[['title', 'main_speaker', 'views', 'comments', 'dis_quo', 'film_date']].sort_values('dis_quo', ascending=False).head(
    10)
# Out:
#                                     title           main_speaker    views  \
# 744        The case for same-sex marriage        Diane J. Savino   292395
# 803                E-voting without fraud          David Bismark   543551
# 96                       Militant atheism        Richard Dawkins  4374792
# 694   Inside a school for suicide bombers  Sharmeen Obaid-Chinoy  1057238
# 954          Taking imagination seriously         Janet Echelman  1832930
# 840                  On reading the Koran        Lesley Hazleton  1847256
# 876          Curating humanity's heritage      Elizabeth Lindsey   439180
# 1787    How do you explain consciousness?         David Chalmers  2162764
# 661          The danger of science denial        Michael Specter  1838628
# 561             Dance to change the world       Mallika Sarabhai   481834
#
#       comments   dis_quo   film_date
# 744        649  0.002220  02-12-2009
# 803        834  0.001534  14-07-2010
# 96        6404  0.001464  02-02-2002
# ...

# %%
df['month'] = df['film_date'].apply(lambda x: month_order[int(x.split('-')[1]) - 1])

# %%
month_df = pd.DataFrame(df['month'].value_counts()).reset_index()
month_df.columns = ['month', 'talks']

# %%
month_df
# Out:
#    month  talks
# 0    Feb    601
# 1    Mar    397
# 2    Jun    270
# 3    Jul    253
# 4    Nov    232
# 5    Oct    208
# 6    Apr    173
# 7    Dec    123
# 8    May    123
# 9    Sep    107
# 10   Jan     33
# 11   Aug     30

# %%
sns.barplot(data=month_df, x='month', y='talks', order=month_order)
# Out:
# <Axes: xlabel='month', ylabel='talks'>

# %%
df_x = df[df['event'].str.contains('TEDx')]

# %%
x_month_df = pd.DataFrame(df_x['month'].value_counts().reset_index())
x_month_df.columns = ['month', 'talks']

# %%
sns.barplot(data=x_month_df, x='month', y='talks', order=month_order)
# Out:
# <Axes: xlabel='month', ylabel='talks'>

# %%
def getday(x):
    day, month, year = (int(i) for i in x.split('-'))
    answer = datetime.date(year=year, month=month, day=day).weekday()
    return day_order[answer]

# %%
df['day'] = df['film_date'].apply(getday)

# %%
day_df = pd.DataFrame(df['day'].value_counts()).reset_index()
day_df.columns = ['day', 'talks']

# %%
sns.barplot(data=day_df, x='day', y='talks', order=day_order)
# Out:
# <Axes: xlabel='day', ylabel='talks'>

# %%
df['year'] = df['film_date'].apply(lambda x: x.split('-')[2])
year_df = pd.DataFrame(df['year'].value_counts()).reset_index()
year_df.columns = ['year', 'talks']

# %%
sns.barplot(data=year_df, x='year', y='talks')
# Out:
# <Axes: xlabel='year', ylabel='talks'>

# %%
plt.figure(figsize=(18, 5))
sns.pointplot(data=year_df, x='year', y='talks')
# Out:
# <Axes: xlabel='year', ylabel='talks'>

# %%
months = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10,
          'Nov': 11, 'Dec': 12}

# %%
hmap_df = df.copy()
hmap_df['film_date'] = hmap_df['film_date'].apply(
    lambda x: month_order[int(x.split('-')[1]) - 1] + " " + x.split('-')[2])
hmap_df = pd.pivot_table(hmap_df[['film_date', 'title']], index='film_date', aggfunc='count').reset_index()
hmap_df['month_num'] = hmap_df['film_date'].apply(lambda x: months[x.split()[0]])
hmap_df['year'] = hmap_df['film_date'].apply(lambda x: x.split()[1])
hmap_df = hmap_df.sort_values(['year', 'month_num'])
hmap_df = hmap_df[['month_num', 'year', 'title']]
hmap_df = hmap_df.pivot(columns=['month_num', 'year', 'title'])
hmap_df = hmap_df.fillna(0)

# %%
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(hmap_df, annot=True, linewidths=.5, ax=ax, fmt='n', yticklabels=month_order)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 2
#       1 f, ax = plt.subplots(figsize=(12, 8))
# ----> 2 sns.heatmap(hmap_df, annot=True, linewidths=.5, ax=ax, fmt='n', yticklabels=month_order)
#
# File ~\Desktop\Arth\AI & ML\TED Data Analysis\venv\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
speaker_df = df.groupby('main_speaker').count().reset_index()[['main_speaker', 'comments']]
speaker_df.columns = ['main_speaker', 'appearance']
speaker_df = speaker_df.sort_values('appearance', ascending=False)
speaker_df.head(10)
# Out:
#               main_speaker  appearance
# 770           Hans Rosling           9
# 1066         Juan Enriquez           7
# 1693                 Rives           6
# 1278         Marco Tempest           6
# 397            Clay Shirky           5
# 1487   Nicholas Negroponte           5
# 1075       Julian Treasure           5
# 424             Dan Ariely           5
# 850   Jacqueline Novogratz           5
# 248             Bill Gates           5
